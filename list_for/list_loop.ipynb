# %%
l1 = ['a', 'b', 'c',
      {
          "username" : "arc",
          "batch" : "arc"
      },
      [1,2,3],True , False
]

# %%
print(l1)
# Out:
# ['a', 'b', 'c', {'username': 'arc', 'batch': 'arc'}, [1, 2, 3], True, False]

# %%
print(f'for loop start')
for l1value in l1:
    print(l1value)
    print('-'*10)
print('for loop end')
