# %%
l1 = ['a', 'b', 'c',
      {
          "username" : "arc",
          "batch" : "arc"
      },
      [1,2,3],True , False
]

# %%
print(l1)
# Out:
# ['a', 'b', 'c', {'username': 'arc', 'batch': 'arc'}, [1, 2, 3], True, False]

# %%
print(f'for loop start')
for l1value in l1:
    print(l1value, type(l1value))
    print('-'*10)
print('for loop end')
# Out:
# for loop start
# a <class 'str'>
# ----------
# b <class 'str'>
# ----------
# c <class 'str'>
# ----------
# {'username': 'arc', 'batch': 'arc'} <class 'dict'>
# ----------
# [1, 2, 3] <class 'list'>
# ----------
# True <class 'bool'>
# ----------
# False <class 'bool'>
# ----------
# for loop end

# %%
l1[0]
print(f"l1[0] = {l1[0]}, type of l1[0] = {type(l1[0])}")
print(f"l1[1] = {l1[1]}, type of l1[1] = {type(l1[1])}")
print(f"l1[2] = {l1[2]}, type of l1[2] = {type(l1[2])}")
print(f"l1[3] = {l1[3]}, type of l1[3] = {type(l1[3])}")
print(f"l1[4] = {l1[4]}, type of l1[4] = {type(l1[4])}")
print(f"l1[5] = {l1[5]}, type of l1[5] = {type(l1[5])}")
print(f"l1[6] = {l1[6]}, type of l1[6] = {type(l1[6])}")
# Out:
# l1[0] = a, type of l1[0] = <class 'str'>
# l1[1] = b, type of l1[1] = <class 'str'>
# l1[2] = c, type of l1[2] = <class 'str'>
# l1[3] = {'username': 'arc', 'batch': 'arc'}, type of l1[3] = <class 'dict'>
# l1[4] = [1, 2, 3], type of l1[4] = <class 'list'>
# l1[5] = True, type of l1[5] = <class 'bool'>
# l1[6] = False, type of l1[6] = <class 'bool'>

# %%
l2 = list(range(1,100))

previous_value = 0

for l2value in l2:
    currentAdd = previous_value + l2value
    previous_value = currentAdd
    print(f"l2 value = {l2value}, currentAdd = {currentAdd}, previous_value = {previous_value}")
    print()
# Out:
# l2 value = 1, currentAdd = 1, previous_value = 1
#
# l2 value = 2, currentAdd = 3, previous_value = 3
#
# l2 value = 3, currentAdd = 6, previous_value = 6
#
# l2 value = 4, currentAdd = 10, previous_value = 10
#
# l2 value = 5, currentAdd = 15, previous_value = 15
#
# l2 value = 6, currentAdd = 21, previous_value = 21
#
# l2 value = 7, currentAdd = 28, previous_value = 28
#
# l2 value = 8, currentAdd = 36, previous_value = 36
#
# l2 value = 9, currentAdd = 45, previous_value = 45
#
# l2 value = 10, currentAdd = 55, previous_value = 55
#
# l2 value = 11, currentAdd = 66, previous_value = 66
#
# l2 value = 12, currentAdd = 78, previous_value = 78
#
# l2 value = 13, currentAdd = 91, previous_value = 91
#
# l2 value = 14, currentAdd = 105, previous_value = 105
#
# l2 value = 15, currentAdd = 120, previous_value = 120
#
# l2 value = 16, currentAdd = 136, previous_value = 136
#
# l2 value = 17, currentAdd = 153, previous_value = 153
#
# ...
