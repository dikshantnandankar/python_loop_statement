# %%
tdata1 = ('I', 'am', 'learning', 'python')

print(f"tdata1 = {tdata1}, type of tdata1 = {type(tdata1)}, length of tdata1 = {len(tdata1)}")
# Out:
# tdata1 = ('I', 'am', 'learning', 'python'), type of tdata1 = <class 'tuple'>, length of tdata1 = 4

# %%
print(f"tdata1[0] = {tdata1[0]}, type of tdata1[0] = {type(tdata1[0])}")
print(f"tdata1[1] = {tdata1[1]}, type of tdata1[1] = {type(tdata1[1])}")
print(f"tdata1[2] = {tdata1[2]}, type of tdata1[2] = {type(tdata1[2])}")
print(f"tdata1[3] = {tdata1[3]}, type of tdata1[3] = {type(tdata1[3])}")
# Out:
# tdata1[0] = I, type of tdata1[0] = <class 'str'>
# tdata1[1] = am, type of tdata1[1] = <class 'str'>
# tdata1[2] = learning, type of tdata1[2] = <class 'str'>
# tdata1[3] = python, type of tdata1[3] = <class 'str'>

# %%
tdata1 = 'sql'
print(tdata1)
# Out:
# sql

# %%
tdata2 = ('d', 3, {"city" : "nagpur"}, [4,6,7])

print(tdata2)

print(tdata2[2])

print(tdata2[2].get('city'))
# Out:
# ('d', 3, {'city': 'nagpur'}, [4, 6, 7])
# {'city': 'nagpur'}
# nagpur

# %%
print(type(tdata2))

tdata2 = list(tdata2)

print(type(tdata2))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
tdata3 = ('f', 'k', 'r', 'r', 'r', 'k', 'i', 't')

print(tdata3)
# Out:
# ('f', 'k', 'r', 'r', 'r', 'k', 'i', 't')
